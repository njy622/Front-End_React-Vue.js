# %% [markdown]
# # 3차시 첫번째 컴포넌트, 분리와 임포트 익스포트, JSX특징, 데이터바인딩

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - App 컴포넌트 : 하나의 화면
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### index.html 이 싱글페이지 어플리케이션에서 싱글페이지에 해당하는것
# - 프로그램이 실행되면서, index.html이 로딩되면서 main.jsx가 실행된다
# - 아래 사진의 노란색표시된 script 태그 부분
# <br>
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 서버 사이드 렌더링: 서버쪽에서 HTML을 다 만들어서 클라이언트로 보내주는 것
# - 클라이언트 서버 렌더링: 서버에서 자바스크립트를 보내주는 것(main.jsx 자바스크립트를 보내줌) 서버에는 index라는 껍데기만 보내주는 것, 그림을 그려주는 로직은 App.jsx에서 그려줌

# %% [markdown]
# - 개발자는 App.jsx인 컴포넌트를 개발하는것(react의 문법에 맞춰서)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 특정 컴포넌트에만 적용되는 로컬 CSS => App.css (App.jsx에 적용)
# - 전체 글로벌 CSS => index.css
# - assets 폴더: 이미지 파일, json 내부데이터 파일 등 포함.
# <br>
# ![image.png](attachment:image.png)

# %% [markdown]
# - 지금 현재는 css파일 사용하지 않으므로 삭제
# - 아래의 사진처럼 3개의 파일이 기본 개발환경 구조
# <br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 컴포넌트의 기본 구조
# ![image.png](attachment:image.png)
# <br>
# - export default App : 다른 컴포넌트에서도 사용할 수 있게 함(컴포지션)

# %% [markdown]
# - 원초적인 main.jsx의 구조
# ![image.png](attachment:image.png)
# <br>
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)<br>
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Css 파일을 만들어서 App.jsx에서 사용하려면 해당 파일에 import를 이용해서 가져와야함
# - jsx에서는 hr,img태그도 항상 닫아줘야함 />
# - jsx에서는 class를 그대로 쓸 수 없고, className=''으로 이름을 지정할 수 있음

# %% [markdown]
# - 컴포넌트는 구조적 특성을 가지고 있다
# - App 컴포넌트를 root 컴포넌트라고 해서, 주위 컴포넌트를 하위컴포넌트라고 하여 구성함
# - App 컴포넌트가 root 컴포넌트
# ![image-2.png](attachment:image-2.png)
#
#     - 아래의 이미지는 하위컴포넌트로 Avatar 컴포넌트를 생성한 것
#     - 하위 컴포넌트는 components 폴더를 생성하여 해당 폴더 안에 넣음
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - default export 하지않으면 에러는 뜨지 않지만 화면이 뜨지 않음
# <br>
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# <br>
# - 네임드 export(default를 쓰지않은 상태)를 하고 싶으면 import할때, {}를 표시해줘야 화면에서 인식
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 프론트엔드 개발을 할때는, static한 데이터보다는<br>
# 변수 생성하여, 변수로 데이터를 바인딩 할 것임
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 하위 컴포넌트와 로컬 CSS를 생성할때, 동일한 이름으로
# ![image.png](attachment:image.png)

# %% [markdown]
# - 이미지 소스도 변수명으로 바인딩 가능
# ![image.png](attachment:image.png)
