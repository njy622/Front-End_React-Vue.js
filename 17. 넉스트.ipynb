# %% [markdown]
# # 17차시. 넉스트

# %% [markdown]
# ![image.png](attachment:image.png)
# https://nuxt.com/docs/getting-started/installation

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 컴포넌트와 아토믹 디자인
# - Atomic Design

# %% [markdown]
# ### 1) 아토믹 디자인 구성
# - 아토믹 디자인은 디자인 시스템을 만드는 하나의 방법론
# - 5개의 구분된 단계가 있음
#     - Atoms(원자)
#     - Molecules (분자)
#     - Organisms(유기체)
#     - Templates
#     - Pages
#     ![image.png](attachment:image.png)

# %% [markdown]
# ### 2) Atoms (원자)
# - 원자는 물질의 기본 빌딩 블록
# - 웹 인터페이스의 텍스트 레이블, 인풋필드, 버튼 등
#     - 컬러팔레트
#     - 폰트
#     - 애니메이션
#
# - 재사용이 중요
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3) Molecules (분자)
# - 원자가 결합된 형태
#     - 화합물의 가장 작은 기본 단위
#     - 그 자체의 특성을 가지고 있음
#     - 디자인 시스템의 중추 역할
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4) Organisms (유기체)
# - 분자들을 결합하여 유기체를 형성
#     - 비교적 복잡하며, 인터페이스에서 구분된 영역을 형성
#     - 헤더, 컨텐츠, 푸터, 사이드 바 등으로 구성 가능
#     - 특정 요소가 반복될 때 사용(카드 등)
#     - 섹션으로 구성 가능
#
#         - Standalone
#         - Portable
#         - Reusable
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5) Templates
# - 고객사와 최종 결과물에 더 적합한 언어 적용
# - 페이지를 구성하기 위해 유기물을 적절히 레이아웃(Wireframe)
# - 분자와 유기체에 대한 맥락(context)을 제공
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6) Pages
# - 템플릿의 특정 인스턴스
#     - 템플릿에 데이터가 추가되면 페이지가 됨
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7) 아토믹 디자인의 장점
# - 구조적 사고 방식
#     - UI 분해 : 틀과 부품
#     - 프론트엔드 개발에서의 컴포넌트 접근법에 적용 가능
#
# - 팀 개발에 응용
#     - 디자이너와 개발자 간의 의사소통이 개선 됨

# %% [markdown]
# ### 8) 컴포넌트와 아토믹 디자인과의 궁합
# - 비대해지지 않는 컴포넌트
#     - 컴포넌트에 너무 많은 기능이 있는 것이 좋지 않음
#     - Atoms이나 Molecules 로 컴포넌트 설계
#     - 설계가 무너지는 컴포넌트 패턴을 피할 수 있음
#     - 최적화, 리팩토링, 유지보수가 쉬워짐 => evolution!
#     - Make catch program do one thing well!
#
# - 확장성
#     - 컴포넌트 단위를 기반으로 조합하는 방법을 사용
#     - 컴포넌트의 집합체로 확장이 가능

# %% [markdown]
# ## 제품의 품질
# - Software Quality

# %% [markdown]
# ### 1) 품질 유지
# - 프론트엔드 역할이 중요해 짐
#
# - 품질 유지와 접근법과 관련된 라이브러리
#     - 테스트 프레임워크
#         - jest-from Facebook  (단위테스트)
#         - Enzyme
#     - Lint  (코드에서 스타일이 잘못되었거나 과한 로직을 걸러낼 수 있음)
#         - ESlint (id레벨에서 적용해서 쓸 수 있음)
#         -StyleLint
#     - 정적 자료형
#         - Flow
#         - Typescript  (사용하는 자체가 품질유지하는것)
#     - 스타일 가이드 활용

# %% [markdown]
# ### 2) 제품의 품질
# - 소프트웨어 품질
#     - 사양을 만족하는가? 버그는 없는가?
#     - 성능(Performance) - 전환용(CVR)과 관련
#     - 접근성(Accessibility)
#     - 확장성(Scalability)
#     - 유지보수성
#     - 문서화
#
# - 소스코드 품질 - 아름다운 코드에 대한 평가
#     - 가독성
#     - 소스코드 변경의 편의성
#     - 테스트 가능 여부

# %% [markdown]
# ### 3) 품질 유지의 필요성과 핵심 포인트
# - 프로그램(서비스)은 시간이 지날수록 품질이 떨어짐
#     - 기술부채가 쌓임 - 새로운 기술이 계속해서 등장
#     - 서비스 변경이 어려워짐
#     - 소스코드 품질이 나빠지면 개선 비용이 증가해 개선이 어려워짐
#
# - 품질 유지의 포인트
#     - 가시성 (데브옵스 또는 코드의 가독성)
#         - 제품 구축 과정에서 가능한 실시간으로 현재의 품질 상태 시각화 필요
#     - 테스트와 리팩토링
#         - 구축 프로세스에 적절히 포함시켜 계속 품질 유지를 실현
#     - 조직
#         - 팀 구성, 의사소통

# %% [markdown]
# ### 4) 컴포넌트 테스트
# - 컴포넌트 정해진 '동작'이 있음
#     - 컴포넌트의 정해진 동작을 일괄적으로 확인하는 작업
#
# - 리액트 컴포넌트는 함수와 같이 동작함
#     - 함수형(Functional) 컴포넌트는 props를 입력받아 render를 반환
#     - 컨테이너형 컴포넌트도 입력이 없을 뿐 출력이 존재
#
# - 리액트 컴포넌트는 각각의 컴포넌트를 단위로 봄
#     - 단위 테스트(Unit Test)의 단위가 컴포넌트가 됨
#
# - 컴포넌트의 로직과 역할에 따른 관점을 가지고 테스트 수행
#     - 컴포넌트 개발자 테스트 케이스를 작성하는 것이 일반적
#     - TDD 도 고려

# %% [markdown]
# ### 5) 테스트 프레임워크
# - 단위테스트는 하나씩 수행하지 않는다.
#     - 단위 테스트를 일괄적으로 수행
#     - 테스트 코드의 작성부터 실행까지 지원하는 것이 테스트 프레임워크
#
# - jest
#     - 리액트 컴포넌트 테스트 프레임워크의 최신판
#     - 페이스북에서 개발
#     - create-react-app 에서 기본으로 제공
#         - npm run test로 테스트 수행

# %% [markdown]
# ### 6) Jest 테스트 구조 분석
# - App 컴포넌트의 테스트 코드
#     - src/App.test.js
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7) ESLint
# - 정적 소스 분석 툴
#
# - JavaScript(ECMAScript) 용 Lint 도구
#     - ESLint가 사용이 쉬워 표준으로 많이 사용됨
#     - 독자적인 규칙을 만들 수 있음
#         - VSCode 확장으로 설치가능
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8) 동적 자료형 언어 VS. 정적 자료형 언어
# - 자료형, Data Type
#     - 자바스크립트는 자료형을 동적으로 할당해 줌 - Dynamic Typing
#     - Dynamic 언어는 사용이 간편할 수 있으나 가독성이 떨어짐
#
# - 자료형의 이점
#     - 리액트는 컴포넌트, 컴포넌트는 재사용
#     - 잘못된 자료형이 전달되었을 때 어느 시점인지를 알기 어려움
#
# - Typescript
#     - MS에서 만든 자바스크립트의 슈퍼셋

# %% [markdown]
# ### 9) 스타일 가이드
# - 스타일 가이드
#     - 프론트엔드에서는 코드 스타일 가이드와 UI 스타일 가이드가 있음
#     - 팀 프로젝트에서 전체 코드나 UI의 스타일의 표준을 정하는 작업
#     - 브랜딩 이미지와 직결
#
# - 에어 비엔비 스타일 가이드
#     - https://github.com/airbnb/javascript
#
# - Storybook
#     - 스타일 가이드 만드는 도구
#     - https://storybook.js.org/

# %% [markdown]
# ## Vue 다음 과정은..

# %% [markdown]
# ### Vue 기본을 넘어서...
# - Nuxt.js
#     - https://kdydesign.github.io/2019/04/10/nuxtjs-tutorial/
#
# - Svelte ?? - next vue or react
#
# - Vue with TypeScript
#     - https://www.typescriptlang.org/
#     - https://kr.vuejs.org/v2/guide/typescript.html
#
# - 프론트엔드 개발자 로드맵
#     - https://github.com/kamranahmedse/developer-roadmap
