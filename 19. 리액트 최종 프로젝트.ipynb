# %% [markdown]
# # 18차시. 리액트 최종 프로젝트

# %% [markdown]
# ## 리액트 영화 앱 - 소개

# %% [markdown]
# - card의 일정 간격 및 배치 만들어주기
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# - 카드에 들어갈 정보 App.jsx에서 데이터 받아오기
# - https://www.themoviedb.org/?language=ko : 회원가입
# ![image.png](attachment:image.png)
# https://www.themoviedb.org/settings/api/request
# https://developer.themoviedb.org/docs/getting-started
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 실습
# - 2번 요청하는 것에 대한 에러 해결
# ![image.png](attachment:image.png)
# - React.StrictMode 태그 제거하였더니, 2번 반복 사라짐
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# - Warning: Invalid DOM property 해당 에러는
# ![image.png](attachment:image.png)
# - 카멜 표시법으로 변경하면됨  ( stroke-linecap => strokeLinecap) / Footer와 Hearder쪽에 있음
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 아래의 에러는 반복문에 key값을 넣어주면 해결
# - id 값을 key 속성으로 넣어줄 것임
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# - 아래의 정보를 이용해서 데이터를 가져올 예정
# ![image.png](attachment:image.png)
# - 이미지를 가져올때 유의사항 (https://developer.themoviedb.org/docs/image-basics)
# ![image-4.png](attachment:image-4.png)
