# %% [markdown]
# # 16차시 라우터 실습1, 라우터 실습 2, 피니아 실습.ipynb

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 초기 로딩을 줄여주기 위해 '/' 외에는 레이지로딩이 들어감<br>
#
# ![image-2.png](attachment:image-2.png)
#
#
# - 경로하나에 하나의 SPA이다. (웹하나다)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 실습
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 상태관리, State management
# - Pinia - global state management

# %% [markdown]
# ### 1) 글로벌 상태관리
# - 로컬 컴포넌트에 데이터를 저장
#     - Props 를 사용해 상태를 공유
#
# ![image.png](attachment:image.png)
#
# - 글로벌에 데이터를 저장(global store)
#     - pinia 사용
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 2) Pinia 란?
# - Vue.js 애플리케이션에서 상태 관리를 위한 경량 라이브러리
#     - Vue.js 공식 상태 관리 라이브러리인 Vuex의 대안으로
#     - Eduardo San Martin Morote에 의해 개발
#     - Vue 3의 Composition API를 활용하여 작성됨
#     - 복잡성을 줄이면서 Vuex에서 제공하는 대부분의 기능을 제공

# %% [markdown]
# - Pinia의 주요 기능
#     - 중앙 집중식 스토어: 애플리케이션의 모든 상태를 중앙에서 관리
#     - 타입스크립트 지원: 코드의 안정성과 개발자의 생산성을 높여줌
#     - Devtools 통합: 상태 변화를 시각적으로 쉽게 추적 및 디버깅 가능
#     - 서버 사이드 렌더링(SSR): 빠른 첫페이지 로딩과 SEO 최적화
#     - 테스트 용이성:
#         - 각 스토어는 독립적으로 생성되고 조작될 수 있어,
#         - 테스트에서 필요한 상태를 쉽게 설정할 수 있습니다.
#     - Vue 2 및 Vue 3 모두와 호환

# %% [markdown]
# ### 3) Pinia 설치
# - 처음부터: npm init vue@latest에서 선택
#
# ![image.png](attachment:image.png)
#
# - 나중에 설정 가능
#     - npm install pinia
#     - main.js에 코드 추가
#
#     ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 4) Pinia로 Store 작성
# - Store
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5) Store 사용
# - Store 는 여러개를 작성/사용 가능
#     - 각각의 store 는 별도의 파일에 작성
#
#     ![image.png](attachment:image.png)

# %% [markdown]
# ### 실습
# ![image.png](attachment:image.png)
# - 페키지 기본 셋팅 : npm install  => 줄여서 npm i 로도 사용가능

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 해당 State들을 App.vue에서 관리하지 않고, store에서 관리

# %% [markdown]
# - store 샵에서 State를 관리
#
# ![image.png](attachment:image.png)
#
# - App.vue에서 store 샵파일을 import받아서 이용
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 자식 컴포넌트에서도 해당 props이용할때 store를 임포트 받아 사용하면됨
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 스토어도 데이터의 양방향 바인딩이 된다
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 컴포넌트에서는 State 관리를 하지 않는다.
# - 컴포넌트에서는 이 데이터값을 Store에서 가져와서 사용할 뿐이다.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
