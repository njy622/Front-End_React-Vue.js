# %% [markdown]
# # 5차시. if for pureing

# %% [markdown]
# ### 2) 조건부 렌더링
# - JSX는 자바스크립트 코드
#     - if 문과 삼항 연산자(? :) 을 이용해 조건부 렌더링이 가능
# <br>
# ![image.png](attachment:image.png)
# <br><br>
#
#     - 논리연산자 && 를 사용한 조건부 렌더링
# <br><br>
# ![<image-2.png>](attachment:image-2.png)
# <br><br>
#
#     - isPacked 가 Ture이면 √ 사용됨, False이면 사용되지 않음

# %% [markdown]
# ### 2) 리스트 렌더링
# - map() 함수를 이용

# %% [markdown]
# - 배열(Arrays) 데이터를 반복적으로 렌더링
#     - 배열 map() 함수를 사용
#     <br><br>
#    ![image.png](attachment:image.png)

# %% [markdown]
# - 순서대로 목록의 항목을 유지하기 위해 key가 필요<br>
# ![image.png](attachment:image.png)
# <br><br>
#     - 각 리스트에 고유한 항목을 제공해야 함
#     ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 오늘의 실습 설계 구조<br>
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# - Item 컴포넌트에서 파라미터에  'isPacked' props를 추가하여조건문을 달아서, PackingList 컴포넌트에서 isPacked의 논리에 따라 다르게 구현하도록 코드를 짬
#
#  ![image.png](attachment:image.png)
#  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 위의 조건문을 간단히 삼항연산자를 이용하여 간결히 작성
# ![image.png](attachment:image.png)

# %% [markdown]
# - 위의 삼항연산자를 더 간결히 논리연산자로 표현
# ![image.png](attachment:image.png)

# %% [markdown]
# - 상황에 맞게 삼항연산자나 논리연산자를 가독성에 좋게 사용하면 됨

# %% [markdown]
# - 리스트 렌더링 반복문 사용하는 방법
# ![image.png](attachment:image.png)

# %% [markdown]
# - data Object를 가져와서 반목문으로 사용해서 표현할 수 있음
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 반복문에서 Key라는 속성을 가지고, 태그의 위치를 표현하는 방법을 사용함
#     - 개발자 도구의 콘솔창을 보면 key 속성을 안주면 아래의 이미지 처럼 경고문이뜸
# ![image.png](attachment:image.png)
# <br><br>
#     - 반복되는 태그에 key 속성을 추가하면 경고문은 사라짐
#    ![image-3.png](attachment:image-3.png)
