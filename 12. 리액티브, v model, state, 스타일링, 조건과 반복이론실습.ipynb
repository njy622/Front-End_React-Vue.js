# %% [markdown]
# # 12차시 리액티브, v model, state, 스타일링, 조건과 반복이론실습

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1) 리액티브 데이터 선언
# - 데이터를 사용하려면 리액티브하게 하자
#     - 주로 객체형 또는 배열로 데이터 선언
#     ![image.png](attachment:image.png)
#     ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 2) 리액티브 데이터 제약 사항
# - reactive()의 두가지 제약 사항
#     - 객체 유형에만 작동 - Object & Array
#     - 리액티브 객체에 동일한 참조를 유지 해야만 함
#     ![image.png](attachment:image.png)
#     ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 3) 리액티브 변수 ref()
# - 리액티브의 제약 사항을 해결하기 위해 ref() 제공
# <br><br>
# ![image.png](attachment:image.png)
# - value 속성을 통해 ref 객체내의 래핑된 인수를 반환
# <br><br>
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 실습
# - ref의 값을 그대로 출력하면 객체로 반환함으로, .value로 해당 데이터를 꺼내 사용할 수 있음
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Styling
# - CSS 처리

# %% [markdown]
# ### 1) HTML 클래스 바인딩
# - CSS 클래스 인라인 바인딩
# <br><br>
# ![image.png](attachment:image.png)
# <br><br>
# - 인라인이 아닌 데이터 전체 바인딩
#  <br><br>
#  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ※( 리액티브 데이터 제약 사항
# - reactive() 의 두가지 제약 사항
#     - 객체 유형에만 작동 - Object & Array
#     - 리액티브 객체에 동일한 참조를 유지 해야만 함
#
# - 변수를 스크립트 내에서 사용할때는 ref()를 이용할것 )

# %% [markdown]
# - 배열에 바인딩
# ![image.png](attachment:image.png)
#
# - 인라인이 아닌 데이터 전체 바인딩
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - v-if와 v-for은 한번에 같이 쓸 수 없음으로,
# ![image.png](attachment:image.png)
#
# span 태그로 감싼후에 v-if 값을 입력하여 사용가능
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# - v-else를 통해 stock=0일 때의 값도 표현
# ![image.png](attachment:image.png)

# %% [markdown]
# - v-for은 유니크한 key값을 항상 주는 것이 좋음
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 폼 바인딩
# - 양방향 바인딩
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1) 양방향 바인딩 :: v-model
# - 양방향 데이터 바인딩
#     - 주로 form 요소에서 사용됨
#         - input text, select box, textarea, radio, button, check box...
#         ![image.png](attachment:image.png)<br>
#         ![image-2.png](attachment:image-2.png)<br><br>
#         - 인풋태그에 글자를 입력하면 데이터의 값이 바뀐다(양방향 바인딩)

# %% [markdown]
# ### 실습
# - 양방향 데이터 바인딩
#
# ![image.png](attachment:image.png)
# <br><br>
# - 인풋창에 입력한 데이터가 변수값에 바인딩 되는 것이다.
# <br>
# ![image-3.png](attachment:image-3.png)
#
# - 체크박스도 동일
# ![image-2.png](attachment:image-2.png)
